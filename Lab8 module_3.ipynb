# %% [markdown]
# <a href="https://colab.research.google.com/github/Raminaidu99/Fmml_modules/blob/main/Lab8%20module_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-23 17:23:29--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   167MB/s    in 0.4s
#
# 2025-03-23 17:23:30 (167 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20114   1410.1776v1  We propose a framework grounded in Logic Progr...    cs
# 40104  1710.11454v1  This paper is concerned with optimization of d...    cs
# 5669   1604.05449v1  It is challenging to handle a large volume of ...  stat
# 32629   1409.7384v2  Feature subset selection, as a special case of...    cs
# 6397   1701.02511v3  Transfer learning leverages the knowledge in o...    cs
# ...             ...                                                ...   ...
# 11364  1511.03688v1  In the current context of data explosion, onli...  stat
# 39515  1607.07129v3  Many man-made objects have intrinsic symmetrie...    cs
# 13322   0912.2310v1  This paper proposes a novel neural-network-bas...    cs
# 6718   1705.08153v2  Long short-term memory (LSTM) recurrent neural...  stat
# 28238  1705.10583v1  Imaging the atmosphere using ground-based sky ...    cs
#
#                                                    title  year  \
# 20114  Ontology-based Representation and Reasoning on...  2014
# 40104  Optimal Resource Allocation in Distributed Bro...  2017
# 5669   Streaming Label Learning for Modeling Labels o...  2016
# 32629  A Semidefinite Programming Based Search Strate...  2014
# 6397   Heterogeneous Transfer Learning: An Unsupervis...  2017
# ...                                                  ...   ...
# 11364  Online Principal Component Analysis in High Di...  2015
# 39515  Exploiting Symmetry and/or Manhattan Propertie...  2016
# 13322      NeuralNetwork Based 3D Surface Reconstruction  2009
# 6718   What does an LSTM look for in classifying hear...  2017
# 28238             Nighttime sky/cloud image segmentation  2017
#
#                                                 keywords
# 20114  [framework, programming, representing, reasoni...
# 40104  [concerned, optimization, distributed, broadba...
# 5669   [challenging, approaches, explicitly, implicit...
# 32629  [selection, selection, considerable, importanc...
# 6397   [leverages, knowledge, efficiency, relatively,...
# ...                                                  ...
# 11364  [explosion, techniques, indispensable, routine...
# 39515  [intrinsic, symmetries, manhattan, structure, ...
# 13322  [reflectance, dimensional, reconstruction, com...
# 6718   [recurrent, uninterpretable, specifically, con...
# 28238  [atmosphere, atmospheric, phenomena, nighttime...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20114    [framework, programming, representing, reasoni...
# 40104    [concerned, optimization, distributed, broadba...
# 5669     [challenging, approaches, explicitly, implicit...
# 32629    [selection, selection, considerable, importanc...
# 6397     [leverages, knowledge, efficiency, relatively,...
#                                ...
# 2994     [expressions, isolation, interactions, recogni...
# 2813     [processes, distributions, functions, generali...
# 13912    [published, ieeexplore, available, amirhossein...
# 21433    [describes, architecture, intelligence, automa...
# 35385    [covariance, selection, likelihood, covariance...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8717 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="91928deb-5688-4464-8e15-0d1186f62766" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91928deb-5688-4464-8e15-0d1186f62766")) {                    Plotly.newPlot(                        "91928deb-5688-4464-8e15-0d1186f62766",                        [{"x":["processes","implementing","structural","seamlessly","preconditions","integrated","following","behavioral","annotations","evaluation","mechanism","including","representation","programming","representing","environment","reasoning","definition","procedure","knowledge","ontological","encouraging","inference","efficient","implement","theoretical","specified","semantics","framework","performed","activities","participating","threefold","combination","effective","transition","experimental","procedural","particular","viability","communication","concerned","optimization","constraint","violation","traditional","connected","designing","communications","application","requirements","departures","locations","determines","determine","distributed","probability","allocation","relationship","regression","benchmark","explicitly","effectively","streaming","minimization","excellent","efficiently","classifiers","approaches","constantly","experiments","environments","performance","extensive","regularization","challenging","empirical","hypotheses","frobenius","generalization","implicitly","classification","relationships","sequential","appropriate","misleading","importance","approximation","selection","algorithm","algorithms","suggested","elimination","conventional","exploiting","addressed","dimensional","information","expansions","applications","heuristic","semidefinite","considered","literature","considerable","polynomial","truncated","reasonable","searching","approximations","similarities","monotonic","instances","progressed","representations","relatively","contribute","leverages","correctness","transferred","situations","minimizing","unlabeled","presented","necessary","principle","sufficient","conditions","principal","homogeneous","efficiency","innovative","guarantee","specifically","unsupervised","preserved","heterogeneous","implemented","grassmann","construct","ubiquitous","computationally","computational","correlation","multivariate","randomness","clustering","component","prohibitive","nonlinear","classical","randomized","canonical","implementation","techniques","statistics","demonstrate","achieving","consecutively","augmentation","architecture","recognition","corrupting","multimodal","ingredients","convolutional","processing","imperfect","ingredient","introduce","realistic","methodology","retrieval","extremely","connectivity","completely","neighbors","attractor","dynamical","stability","abilities","associative","functions","strategies","scenarios","considerations","formulation","diffusion","different","furthermore","dictionaries","variables","minimized","dictionary","associated","coefficient","aggregation","generates","individual","collaborative"],"y":[105,17,71,7,2,49,80,12,71,258,129,262,354,116,60,127,136,47,122,327,5,24,223,398,69,162,37,84,533,122,35,10,4,119,251,27,365,3,268,9,53,19,313,79,8,161,85,52,10,235,42,2,39,12,82,105,163,20,85,120,205,81,120,23,57,25,153,117,461,4,617,79,863,196,85,277,145,19,4,101,20,545,64,72,66,7,80,121,148,797,641,24,10,94,75,38,185,679,5,438,66,6,124,114,46,64,10,28,31,31,44,15,108,3,228,54,26,26,21,12,44,41,57,178,74,55,68,132,38,15,150,16,41,143,128,12,36,104,4,87,12,96,303,68,23,6,145,102,9,53,105,26,18,109,354,65,582,80,3,24,246,367,1,23,7,404,293,11,4,323,62,58,97,54,25,35,24,2,17,35,14,10,236,94,82,8,94,20,723,160,21,142,8,55,117,24,31,43,110,40],"type":"bar"},{"x":["processes","implementing","structural","seamlessly","preconditions","integra ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style=''>Leads</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Overfitting</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structure</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Regularization</span> <span style=''>Decoding</span> <span style=''>Method</span> <span style=''>for</span> <span style=''>Natural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.4292682926829268);'>Processing</span> <br/><br/><span style=''>Recent</span> <span style=''>systems</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>focus</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.30120481927710835);'>increasing</span> <span style=''>the</span> <span style=''>level</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>within</span> <span style=''>the</span> <span style=''>model</span> <span style=''>However</span> <span style=''>our</span> <span style=''>study</span> <span style=''>suggests</span> <span style=''>that</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>entail</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>risks</span> <span style=''>To</span> <span style=''>control</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>conduct</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>regularization</span> <span style=''>decoding</span> <span style=''>(SR</span> <span style=''>decoding)</span> <span style=''>The</span> <span style=''>decoding</span> <span style=''>of</span> <span style=''>the</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.34666666666666673);'>regularized</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additionally</span> <span style=''>trained</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>model</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.485148514851485);'>quantitative</span> <span style='background-color:rgba(0, 255, 0, 0.42148760330578505);'>relations</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>risk</span> <span style=''>The</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>models</span> <span style=''>are</span> <span style=''>prone</span> <span style=''>to</span> <span style=''>the</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>possible</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>using</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style=''>acyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>specific</span> <span style=''>effects</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>possible</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>of</span> <span style=''>two</span> <span style=''>observed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Several</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistently</span> <span style=''>estimate</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>direction</span> <span style=''>assuming</span> <span style=''>linear</span> <span style=''>or</span> <span style=''>some</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationship</span> <span style=''>and</span> <span style=''>no</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>results</span> <span style=''>could</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distorted</span> <span style=''>if</span> <span style=''>either</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>actually</span> <span style=''>violated</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>linear</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style=''>acyclic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style=''>equation</span> <span style=''>model</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>specific</span> <span style=''>effects</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confounders</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>We</span> <span style=''>then</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>Markov</span> <span style=''>Decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarially</span> <span style=''>Chosen</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Transition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributions</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>finite</span> <span style=''>state</span> <span style=''>and</span> <span style=''>action</span> <span style=''>spaces</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style=''>and</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>are</span> <span style=''>chosen</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarially</span> <span style=''>and</span> <span style=''>are</span> <span style=''>allowed</span> <span style=''>to</span> <span style=''>change</span> <span style=''>with</span> <span style=''>time</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>whose</span> <span style=''>regret</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>any</span> <span style=''>policy</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>class</span> <span style=''>grows</span> <span style=''>as</span> <span style=''>the</span> <span style=''>square</span> <span style=''>root</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>rounds</span> <span style=''>of</span> <span style=''>the</span> <span style=''>game</span> <span style=''>provided</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>satisfy</span> <span style=''>a</span> <span style=''>uniform</span> <span style=''>mixing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>as</span> <span style=''>long</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>class</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>and</span> <span style=''>we</span> <span style=''>can</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>over</span> <span style=''>sample</span> <span style=''>paths</span> <span style=''>for</span> <span style=''>each</span> <span style=''>policy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Designing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>BaTFLED</span> <span style=''>Bayesian</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Linked</span> <span style=''>to</span> <span style=''>External</span> <span style=''>Data</span> <br/><br/><span style=''>The</span> <span style=''>vast</span> <span style=''>majority</span> <span style=''>of</span> <span style=''>current</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>or</span> <span style=''>a</span> <span style=''>vector</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>responses</span> <span style=''>yet</span> <span style=''>many</span> <span style=''>types</span> <span style=''>of</span> <span style=''>response</span> <span style=''>are</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organized</span> <span style=''>as</span> <span style=''>matrices</span> <span style=''>or</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>tensor</span> <span style=''>objects</span> <span style=''>where</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characteristics</span> <span style=''>are</span> <span style=''>shared</span> <span style=''>across</span> <span style=''>modes</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>BaTFLED</span> <span style=''>(Bayesian</span> <span style=''>Tensor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Factorization</span> <span style=''>Linked</span> <span style=''>to</span> <span style=''>External</span> <span style=''>Data)</span> <span style=''>that</span> <span style=''>predicts</span> <span style=''>values</span> <span style=''>in</span> <span style=''>a</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>response</span> <span style=''>tensor</span> <span style=''>using</span> <span style=''>input</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>BaTFLED</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>matrices</span> <span style=''>mapping</span> <span style=''>input</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>mode</span> <span style=''>into</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>multiply</span> <span style=''>to</span> <span style=''>form</span> <span style=''>the</span> <span style=''>response</span> <span style=''>tensor</span> <span style=''>By</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style=''>a</span> <span style=''>Tucker</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style=''>the</span> <span style=''>model</span> <span style=''>can</span> <span style=''>capture</span> <spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09889325240985362)
# 	representation (0.12638343448768297)
# 	processing (0.10460549803641557)
# 	architecture (0.08782577650838987)
# 	information (0.24241342377722241)
# 	different (0.25812209925026774)
# 	segmentation (0.08104248482684756)
# 	detection (0.12638343448768297)
# 	recognition (0.13102463405926454)
# 	convolutional (0.14423420207068904)
#
# Some Statistics words are:
# 	stochastic (0.13856928464232116)
# 	variables (0.14007003501750875)
# 	distribution (0.18209104552276137)
# 	algorithm (0.38219109554777386)
# 	theoretical (0.15607803901950976)
# 	statistical (0.1535767883941971)
# 	inference (0.18309154577288644)
# 	estimation (0.17358679339669836)
# 	dimensional (0.18609304652326164)
# 	regression (0.1855927963981991)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="960d2376-a2ce-472e-a675-3bea0f52ea13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("960d2376-a2ce-472e-a675-3bea0f52ea13")) {                    Plotly.newPlot(                        "960d2376-a2ce-472e-a675-3bea0f52ea13",                        [{"x":["processes","implementing","structural","seamlessly","preconditions","integrated","following","behavioral","annotations","evaluation","mechanism","including","representation","programming","representing","environment","reasoning","definition","procedure","knowledge","ontological","encouraging","inference","efficient","implement","theoretical","specified","semantics","framework","performed","activities","participating","threefold","combination","effective","transition","experimental","procedural","particular","viability","communication","concerned","optimization","constraint","violation","traditional","connected","designing","communications","application","requirements","departures","locations","determines","determine","distributed","probability","allocation","relationship","regression","benchmark","explicitly","effectively","streaming","minimization","excellent","efficiently","classifiers","approaches","constantly","experiments","environments","performance","extensive","regularization","challenging","empirical","hypotheses","frobenius","generalization","implicitly","classification","relationships","sequential","appropriate","misleading","importance","approximation","selection","algorithm","algorithms","suggested","elimination","conventional","exploiting","addressed","dimensional","information","expansions","applications","heuristic","semidefinite","considered","literature","considerable","polynomial","truncated","reasonable","searching","approximations","similarities","monotonic","instances","progressed","representations","relatively","contribute","leverages","correctness","transferred","situations","minimizing","unlabeled","presented","necessary","principle","sufficient","conditions","principal","homogeneous","efficiency","innovative","guarantee","specifically","unsupervised","preserved","heterogeneous","implemented","grassmann","construct","ubiquitous","computationally","computational","correlation","multivariate","randomness","clustering","component","prohibitive","nonlinear","classical","randomized","canonical","implementation","techniques","statistics","demonstrate","achieving","consecutively","augmentation","architecture","recognition","corrupting","multimodal","ingredients","convolutional","processing","imperfect","ingredient","introduce","realistic","methodology","retrieval","extremely","connectivity","completely","neighbors","attractor","dynamical","stability","abilities","associative","functions","strategies","scenarios","considerations","formulation","diffusion","different","furthermore","dictionaries","variables","minimized","dictionary","associated","coefficient","aggregation","generates","individual","collaborative","aggregate","construction","bilingual","automatically","databases","hierarchies","translations","multilingual","connections","monolingual","resources","satisfaction","relaxation","automatic","candidate","technique","ensembles","documents","factorization","probabilistic","combining","stochastic","instability","potentially","generated","underlying","previously","structure","simultaneously","structured","implementations","definitive","parameter","corresponds","initialization","significantly","annotated","considerably","dimensions","preserving","deteriorate","repositories","estimator","bootstrap","parameters","practically","unfortunately","statistical","reduction","statistically","additional","practical","degenerate","applicable","introduces","es ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	degenerate
# 	disentangles
# 	postulated
# 	intersect
# 	initialise
# 	imputations
# 	amortised
# 	physician
# 	integrand
# 	tempering
# 	differentiability
# 	spectrometry
# 	methodologically
# 	quadratically
# 	eigenstructures
# 	blockwise
# 	individualized
# 	marginalizing
# 	subgaussian
# 	pharmaceutical
# Some words which never appear in Statistics papers:
# 	preconditions
# 	ontological
# 	departures
# 	consecutively
# 	imperfect
# 	bilingual
# 	monolingual
# 	definitive
# 	memorable
# 	repeatable
# 	remembering
# 	celebrities
# 	readability
# 	summarizer
# 	extractive
# 	summarizers
# 	abstractive
# 	upsampling
# 	artefacts
# 	charbonnier

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0706872197997915e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7541666666666667
